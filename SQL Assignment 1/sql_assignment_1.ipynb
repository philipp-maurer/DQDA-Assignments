# %%
# run `!pip install ipython-sql` to install sql module
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://student:KUOgN6chetHuZ9f9wZ0c@dsc-inf.postgres.database.azure.com/music-store

# %% [markdown]
# Run Query: Retrieve all data from the artists table. Look at the list of artists, how many artists are you familiar with (there is no wrong answer here)

# %%
# %sql select * from artists limit 5
# Out:
#  * postgresql://student:***@dsc-inf.postgres.database.azure.com/music-store
# 5 rows affected.
# [(1, 'AC/DC'),
#  (2, 'Accept'),
#  (3, 'Aerosmith'),
#  (4, 'Alanis Morissette'),
#  (5, 'Alice In Chains')]

# %%
# bis auf "Accept" alle ;-)

# %% [markdown]
# Run Query: Find all the tracks that have a length of 5,000,000 milliseconds or more. **How many tracks are returned?**

# %%
# %sql SELECT COUNT(id) FROM tracks WHERE milliseconds >= 5000000;
# Out:
#  * postgresql://student:***@dsc-inf.postgres.database.azure.com/music-store
# 1 rows affected.
# [(2,)]

# %% [markdown]
# Run Query: Find all the invoices whose total is between 5 and 15 dollars.

# %%
# %sql SELECT * FROM invoices WHERE total BETWEEN 5 AND 15;
# Out:
#  * postgresql://student:***@dsc-inf.postgres.database.azure.com/music-store
# 168 rows affected.
# [(3, 8, datetime.datetime(2009, 1, 3, 0, 0), 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', Decimal('5.94')),
#  (4, 14, datetime.datetime(2009, 1, 6, 0, 0), '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', Decimal('8.91')),
#  (5, 23, datetime.datetime(2009, 1, 11, 0, 0), '69 Salem Street', 'Boston', 'MA', 'USA', '2113', Decimal('13.86')),
#  (10, 46, datetime.datetime(2009, 2, 3, 0, 0), '3 Chatham Street', 'Dublin', 'Dublin', 'Ireland', None, Decimal('5.94')),
#  (11, 52, datetime.datetime(2009, 2, 6, 0, 0), '202 Hoxton Street', 'London', None, 'United Kingdom', 'N1 5LH', Decimal('8.91')),
#  (12, 2, datetime.datetime(2009, 2, 11, 0, 0), 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', Decimal('13.86')),
#  (17, 25, datetime.datetime(2009, 3, 6, 0, 0), '319 N. Frances Street', 'Madison', 'WI', 'USA', '53703', Decimal('5.94')),
# ...

# %% [markdown]
# Run Query: Find all the customers from the following States: RJ, DF, AB, BC, CA, WA, NY.

# %%
# %sql SELECT * FROM customers WHERE State IN ('RJ','DF','AB','BC','CA','WA','NY');
# Out:
#  * postgresql://student:***@dsc-inf.postgres.database.azure.com/music-store
# 9 rows affected.
# [(12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3),
#  (13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4),
#  (14, 'Mark', 'Philips', 'Telus', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', '+1 (780) 434-4554', '+1 (780) 434-5565', 'mphilips12@shaw.ca', 5),
#  (15, 'Jennifer', 'Peterson', 'Rogers Canada', '700 W Pender Street', 'Vancouver', 'BC', 'Canada', 'V6C 1G8', '+1 (604) 688-2255', '+1 (604) 688-8756', 'jenniferp@rogers.ca', 3),
#  (16, 'Frank', 'Harris', 'Google Inc.', '1600 Amphitheatre Parkway', 'Mountain View', 'CA', 'USA', '94043-1351', '+1 (650) 253-0000', '+1 (650) 253-0000', 'fharris@google.com', 4),
# ...

# %% [markdown]
# What company does Jack Smith work for?

# %%
# %sql SELECT company FROM customers WHERE last_name = 'Smith' AND first_name = 'Jack';
# Out:
#  * postgresql://student:***@dsc-inf.postgres.database.azure.com/music-store
# 1 rows affected.
# [('Microsoft Corporation',)]

# %% [markdown]
# Run Query: Find all the invoices for customer 56 and 58 where the total was between 1.00 and 5.00 dollars.

# %%
# %sql SELECT id, customer_id, total FROM invoices WHERE customer_id IN (56, 58) AND (total BETWEEN 1.00 AND 5.00);
# Out:
#  * postgresql://student:***@dsc-inf.postgres.database.azure.com/music-store
# 7 rows affected.
# [(119, 56, Decimal('1.98')),
#  (120, 58, Decimal('1.98')),
#  (142, 56, Decimal('3.96')),
#  (315, 58, Decimal('1.98')),
#  (337, 56, Decimal('1.98')),
#  (338, 58, Decimal('3.96')),
#  (412, 58, Decimal('1.99'))]

# %% [markdown]
# What was the invoice date for invoice ID 315?

# %%
# %sql SELECT invoice_date FROM invoices WHERE id = 315;
# Out:
#  * postgresql://student:***@dsc-inf.postgres.database.azure.com/music-store
# 1 rows affected.
# [(datetime.datetime(2012, 10, 27, 0, 0),)]

# %% [markdown]
# Run Query: Find all the tracks whose name starts with 'All'. **How many total records there are for this query?**

# %%
# %sql SELECT COUNT(*) FROM tracks WHERE name LIKE 'All%';
# Out:
#  * postgresql://student:***@dsc-inf.postgres.database.azure.com/music-store
# 1 rows affected.
# [(15,)]

# %% [markdown]
# Run Query: Find all the customer emails that start with "J" and are from gmail.com.

# %%
# %sql SELECT email FROM customers WHERE email LIKE lower('J%gmail.com');
# Out:
#  * postgresql://student:***@dsc-inf.postgres.database.azure.com/music-store
# 1 rows affected.
# [('jubarnett@gmail.com',)]

# %% [markdown]
# Run Query: Find the albums with 12 or more tracks.

# %%
# %sql SELECT t.album_id, a.title, COUNT(*) FROM albums a, tracks t WHERE a.id = t.album_id GROUP BY t.album_id, a.title HAVING COUNT(*) >= 12 ORDER BY 3;
# Out:
#  * postgresql://student:***@dsc-inf.postgres.database.azure.com/music-store
# 158 rows affected.
# [(148, 'Black albums', 12),
#  (232, 'Achtung Baby', 12),
#  (245, 'Van Halen III', 12),
#  (242, 'Diver Down', 12),
#  (168, 'Arquivo II', 12),
#  (256, 'Speak of the Devil', 12),
#  (236, 'Pop', 12),
#  (12, 'BackBeat Soundtrack', 12),
#  (95, 'A Real Dead One', 12),
#  (99, 'Fear Of The Dark', 12),
#  (199, 'Maquinarama', 12),
#  (321, 'Back to Black', 12),
#  (175, 'Walking Into Clarksdale', 12),
#  (74, 'albums Of The Year', 12),
#  (123, 'Jota Quest-1995', 12),
#  (182, 'Vs.', 12),
#  (7, 'Facelift', 12),
#  (63, 'Purpendicular', 12),
#  (11, 'Out Of Exile', 12),
#  (257, '20th Century Masters - The Millennium Collection: The Best of Scorpions', 12),
#  (216, 'Hot Rocks, 1964-1971 (Disc 1)', 12),
#  (40, 'Into The Light', 12),
#  (161, 'Demorou...', 12),
#  (206, 'Core', 12),
#  (164, 'Nevermind', 12),
#  (38, 'Heart of the Night', 12),
#  (88, 'Faceless', 12),
# ...
